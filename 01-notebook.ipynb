# %%
print("Hello world!")

# %% [markdown]
# ## Text for test

# %%
# 마지막에 자동 print
a = 12
b = 6
b
c = a / b
c

# %%
arr = [1, 2, 3, 4, 5]

sum(arr)
# Out:
# 15

# %%
# ?sum

# %%
# !python --version
# !ls
# Out:
# Python 3.6.8
# blooth_sales_data.csv  blooth_sales_data.xlsx  drive  sample_data

# %%
# timeit
def algorithm1(x):
  sum = 0
  for a in x:
    sum += (a * 2)
  return sum

def algorithm2(x):
  sum = 0
  for a in x:
    for i in range(10000):
      sum += (a * 2)
  return sum

# %timeit x = algorithm1(range(1000))
print('---')
# %timeit x = algorithm2(range(1000))
# Out:
# The slowest run took 5.00 times longer than the fastest. This could mean that an intermediate result is being cached.
# 10000 loops, best of 3: 66.6 µs per loop
# ---
# 1 loop, best of 3: 752 ms per loop

# %% [markdown]
# ## Plot

# %%
# plot
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(1)

x = np.random.normal(5, 2, 10000)
y = np.random.normal(2, 1, 3000000)

xweights = 100 * np.ones_like(x) / x.size
yweights = 100 * np.ones_like(y) / y.size

fig, ax = plt.subplots()
ax.hist(x, weights=xweights, color='lightblue', alpha=0.5, density=True)
ax.hist(y, weights=yweights, color='salmon', alpha=0.5, density=True)

ax.set(title='Histogram Comparison', ylabel='% of Dataset in Bin')
ax.margins(0.05)
ax.set_ylim(bottom=0)
plt.show()

# %%
# !ls
# !pwd
# !echo -----
# !ls sample_data
# Out:
# sample_data
# /content
# -----
# anscombe.json		      mnist_test.csv
# california_housing_test.csv   mnist_train_small.csv
# california_housing_train.csv  README.md

# %%
with open('sample_data/california_housing_train.csv') as f:
  content = f.read()
# print(content)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls /content/drive/'My Drive/Colab Notebooks/sales_data.csv'
# Out:
# '/content/drive/My Drive/Colab Notebooks/sales_data.csv'

# %%
# !wget https://raw.githubusercontent.com/alanderex/pydata-pandas-workshop/master/data/blooth_sales_data.csv
# Out:
# --2019-11-16 16:35:35--  https://raw.githubusercontent.com/alanderex/pydata-pandas-workshop/master/data/blooth_sales_data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 89685 (88K) [text/plain]
# Saving to: ‘blooth_sales_data.csv.1’
#
# blooth_sales_data.c 100%[===================>]  87.58K  --.-KB/s    in 0.01s
#
# 2019-11-16 16:35:35 (5.97 MB/s) - ‘blooth_sales_data.csv.1’ saved [89685/89685]

# %%
# !ls
# Out:
# blooth_sales_data.csv	 blooth_sales_data.xlsx  sample_data
# blooth_sales_data.csv.1  drive

# %%
# pd.set_option('display.max_rows', 10000)

# %%
sales_data = pd.read_csv('blooth_sales_data.csv',
                         parse_dates=['birthday', 'orderdate'],
                         dayfirst=True)
sales_data.head(5)
# Out:
#        name   birthday  ... units unitprice
# 0  Pasquale 1967-09-02  ...     2     13.27
# 1     India 1968-12-13  ...    26  24458.69
# 2     Wayne 1992-09-10  ...    41     15.79
# 3      Cori 1986-11-05  ...    16    584.01
# 4     Chang 1972-04-23  ...     4     25.69
#
# [5 rows x 7 columns]

# %%
sales_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
# name         1000 non-null object
# birthday     1000 non-null datetime64[ns]
# customer     1000 non-null object
# orderdate    1000 non-null datetime64[ns]
# product      1000 non-null object
# units        1000 non-null int64
# unitprice    1000 non-null float64
# dtypes: datetime64[ns](2), float64(1), int64(1), object(3)
# memory usage: 54.8+ KB

# %%
sales_data.tail()
# Out:
#          name   birthday  ... units unitprice
# 995     Ethan 1952-12-08  ...    39     24.40
# 996   Rudolph 1959-10-15  ...     9     15.11
# 997  Annmarie 1982-06-04  ...    19      9.16
# 998     Chang 1984-02-05  ...    24     28.21
# 999     Ervin 1977-10-14  ...    39    663.83
#
# [5 rows x 7 columns]

# %%
# !wget https://raw.githubusercontent.com/alanderex/pydata-pandas-workshop/master/data/blooth_sales_data.xlsx
# Out:
# --2019-11-16 14:47:38--  https://raw.githubusercontent.com/alanderex/pydata-pandas-workshop/master/data/blooth_sales_data.xlsx
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63927 (62K) [application/octet-stream]
# Saving to: ‘blooth_sales_data.xlsx’
#
# blooth_sales_data.x 100%[===================>]  62.43K  --.-KB/s    in 0.01s
#
# 2019-11-16 14:47:38 (4.26 MB/s) - ‘blooth_sales_data.xlsx’ saved [63927/63927]

# %%
sales_data = pd.read_excel('blooth_sales_data.xlsx',
                         parse_dates=['birthday', 'orderdate'],
                         dayfirst=True)

# %%
sales_data.head()
# Out:
#        name   birthday  ... units unitprice
# 0  Pasquale 1967-09-02  ...     2     13.27
# 1     India 1968-12-13  ...    26  24458.69
# 2     Wayne 1992-09-10  ...    41     15.79
# 3      Cori 1986-11-05  ...    16    584.01
# 4     Chang 1972-04-23  ...     4     25.69
#
# [5 rows x 7 columns]
