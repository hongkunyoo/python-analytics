# %% [markdown]
# ## Diamond Datasets

# %%
# !rm -rf diamonds.csv && wget https://raw.githubusercontent.com/hongkunyoo/python-analytics/master/diamonds.csv
import pandas as pd

df = pd.read_csv('diamonds.csv', index_col='id')
df.head(100)
# Out:
# --2019-11-16 19:32:35--  https://raw.githubusercontent.com/hongkunyoo/python-analytics/master/diamonds.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2960856 (2.8M) [text/plain]
# Saving to: ‘diamonds.csv’
#
# diamonds.csv        100%[===================>]   2.82M  --.-KB/s    in 0.1s
#
# 2019-11-16 19:32:35 (27.7 MB/s) - ‘diamonds.csv’ saved [2960856/2960856]
#     carat        cut color clarity  depth  table   price     x     y     z
# id
# 0    0.23      Ideal     E     SI2   61.5   55.0   326.0  3.95  3.98  2.43
# 1    0.21    Premium     E     SI1   59.8   61.0   326.0  3.89  3.84  2.31
# 2    0.23       Good     E     VS1   56.9   65.0   327.0  4.05  4.07  2.31
# 3    0.29    Premium     I     VS2   62.4   58.0   334.0  4.20  4.23  2.63
# ...

# %% [markdown]
# ## 분석 실습

# %% [markdown]
# ### 가격 상위 10개의 총합은?

# %% [markdown]
# ### 색깔별 개수 (count)

# %% [markdown]
# ### cut별 평균 depth 값

# %% [markdown]
# ### carat별 volume 평균 (x, y, z가 직사각형 가정)

# %% [markdown]
# ### 0.01 carat 당 최고가

# %% [markdown]
# ### price가 NaN인 개수와 값이 있는 개수

# %% [markdown]
# ### NaN의 price를 예측하시오.

# %%
# !rm -rf validator.py && wget https://raw.githubusercontent.com/hongkunyoo/python-analytics/master/validator.py
# Out:
# --2019-11-16 19:39:15--  https://raw.githubusercontent.com/hongkunyoo/python-analytics/master/validator.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 281 [text/plain]
# Saving to: ‘validator.py’
#
# validator.py        100%[===================>]     281  --.-KB/s    in 0s
#
# 2019-11-16 19:39:15 (68.0 MB/s) - ‘validator.py’ saved [281/281]
# '21237885.0'

# %%
import validator

validator.request(df)
# Out:
# '21237885.0'
